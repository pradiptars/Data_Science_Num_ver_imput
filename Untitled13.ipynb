# %% [markdown]
# <a href="https://colab.research.google.com/github/pradiptars/Data_Science_Num_ver_imput/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer

# %%
test = pd.read_csv(r'/test.csv')
train = pd.read_csv(r'/train.csv')

# %%
print("shape of test :", test.shape)
print("shape of train :", train.shape)
# Out:
# shape of test : (418, 12)
# shape of train : (891, 12)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
X_train = train.drop(columns=['Survived'])
y_train = train['Survived']

# %%
print("shape of test :", X_train.shape)
print("shape of train :", y_train.shape)
# Out:
# shape of test : (891, 11)
# shape of train : (891,)

# %%
num_var = X_train.select_dtypes(include=['int64', 'float64']).columns
num_var
# Out:
# Index(['PassengerId', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
X_train[num_var].isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Age            177
# SibSp            0
# Parch            0
# Fare             0
# dtype: int64

# %%
imputer_mean = SimpleImputer(strategy='mean')

# %%
imputer_mean.fit(X_train[num_var])
# Out:
# SimpleImputer()

# %%
imputer_mean.statistics_
# Out:
# array([4.46000000e+02, 2.30864198e+00, 2.96991176e+01, 5.23007856e-01,
#        3.81593715e-01, 3.22042080e+01])

# %%
imputer_mean.transform(X_train[num_var])
# Out:
# array([[  1.        ,   3.        ,  22.        ,   1.        ,
#           0.        ,   7.25      ],
#        [  2.        ,   1.        ,  38.        ,   1.        ,
#           0.        ,  71.2833    ],
#        [  3.        ,   3.        ,  26.        ,   0.        ,
#           0.        ,   7.925     ],
#        ...,
#        [889.        ,   3.        ,  29.69911765,   1.        ,
#           2.        ,  23.45      ],
#        [890.        ,   1.        ,  26.        ,   0.        ,
#           0.        ,  30.        ],
#        [891.        ,   3.        ,  32.        ,   0.        ,
#           0.        ,   7.75      ]])

# %%
X_train[num_var] = imputer_mean.transform(X_train[num_var])
test[num_var] = imputer_mean.transform(test[num_var])

# %%
X_train[num_var].isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# dtype: int64

# %%
test[num_var].isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# dtype: int64

# %%
cat_var = X_train.select_dtypes(include=['O']).columns
cat_var
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
X_train[cat_var].isnull().sum()
# Out:
# Name          0
# Sex           0
# Ticket        0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
imputer_mode = SimpleImputer(strategy='most_frequent')
imputer_mode
# Out:
# SimpleImputer(strategy='most_frequent')

# %%
imputer_mode.fit(X_train[cat_var])
# Out:
# SimpleImputer(strategy='most_frequent')

# %%
X_train[cat_var] = imputer_mode.transform(X_train[cat_var])
test[cat_var] = imputer_mode.transform(test[cat_var])

# %%
X_train[cat_var].isnull().sum()
# Out:
# Name        0
# Sex         0
# Ticket      0
# Cabin       0
# Embarked    0
# dtype: int64

# %%
test[cat_var].isnull().sum()
# Out:
# Name        0
# Sex         0
# Ticket      0
# Cabin       0
# Embarked    0
# dtype: int64

# %%
X_train.isnull().sum().sum()
# Out:
# 0
